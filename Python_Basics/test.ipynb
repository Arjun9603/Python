# %%
1+1
# Out:
# 2

# %% [markdown]
# Syntax

# %% [markdown]
# Syntax refers to the set of rules that define the combination of symbols that are considered to be correctly structured programs in a language. syntax is about the correct arrangement of words and symbols in a code.

# %% [markdown]
# Semantics

# %% [markdown]
# Semantics refer to the meaning or the interpretation of symbols, characters and commands in a language. It is about what the code is supposed to do when it runs.

# %%
name="Arjun"
Name="Raghav"
print(name+" "+Name)
# Out:
# Arjun Raghav

# %%
#Indentation
#Indentation is used to define blocks of code. Consistent use of spaces(commonly 4 ) or a tab is required.


#indentation is crucial for defining code blocks and maintaining the structure of your program

# %%
#Line Continuation:
total=1+2+3+4+5+\
8+6
print(total)
# Out:
# 29
